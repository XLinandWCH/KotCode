// %%
%useLatestDescriptors
%use koog
// Out:
// WARNING: Can't resolve library koog from the given reference. Using classpath version of this library. Error: java.net.UnknownHostException: raw.githubusercontent.com
